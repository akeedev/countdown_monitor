# %%
#
# pytesseract requires tesseract to be installed at OS level,
# e.g. > brew install tesseract
#
# !pip install pytesseract
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 7.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pytesseract]
# ...

# %%
#
# Demos screenshot (will require permissions in MacOS system settings)
#
import mss

with mss.mss() as sct:
    # Monitor 1, oder spezifische Region
    screenshot = sct.grab(sct.monitors[1])
    mss.tools.to_png(screenshot.rgb, screenshot.size, output="test.png")

# %%
from countdown_monitor import save_region, load_region, select_region, capture_region, extract_number, run_detection

region = select_region()
if region:
    save_region(region)
# Out:
# === Region Selection ===
# 1. Taking full screenshot...
# 2. Select the countdown region (drag a rectangle)
#    Press ENTER to confirm, C to cancel
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Selection cancelled.

# %%
region = load_region()
if not region:
    print("No region configured. Run with --setup first.")
    return
img = capture_region(region)
cv2.imwrite("test_capture.png", img)
number = extract_number(img)
print(f"Captured region saved to test_capture.png")
print(f"Detected number: {number}")

# %%
region = load_region()
if not region:
    print("No region configured. Run with --setup first.")
    return
run_detection(region)

# %%
k = {1: "a", 5:"b"}

# %%
1 in k

# %%
max(i for i in k)

# %%
k
